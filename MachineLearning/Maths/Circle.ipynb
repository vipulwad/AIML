# %%
import matplotlib.pyplot as plt
import numpy as np
import math
plt.figure(figsize=(8,8))
circle_theta=np.linspace(0, 2*math.pi, 150)
# circle_theta
c_x=100
c_y=100
radius=20
X=c_x+radius* np.cos(circle_theta)
Y=c_y+radius* np.sin(circle_theta)

#generate points
theta_in_radian=math.radians(45)
p_x=c_x+10*np.cos(theta_in_radian)
p_y=c_y+10*np.sin(theta_in_radian)
print(p_x, p_y)

# plotting
plt.plot(X,Y)
plt.plot([c_x-radius, c_x+radius], [c_y, c_y])
plt.plot([c_x, c_x], [c_y-radius, c_y+radius])
plt.scatter(p_x, p_y)
plt.axis('equal')
plt.show()
# Out:
# 107.07106781186548 107.07106781186548

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random
# plt.figure(figsize=(8,8))
circle_theta=np.linspace(0, 2*math.pi, 150)
# circle_theta
c_x=100
c_y=100
radius=20
X=c_x+radius* np.cos(circle_theta)
Y=c_y+radius* np.sin(circle_theta)

#generate points
p_x=[]
p_y=[]
num=np.random.randint(0,360, 1000)
print(num)

for i in num:
  theta_in_radian=math.radians(i)
  r=np.random.randint(0,radius, 1)
  p_x.append(c_x + r*np.cos(theta_in_radian))
  p_y.append(c_y + r*np.sin(theta_in_radian))
print(len(p_x), len(p_y))

# theta_in_radian=math.radians(45)
# p_x=c_x+10*np.cos(theta_in_radian)
# p_y=c_y+10*np.sin(theta_in_radian)
# print(p_x, p_y)

# plotting
plt.plot(X,Y)
plt.plot([c_x-radius, c_x+radius], [c_y, c_y])
plt.plot([c_x, c_x], [c_y-radius, c_y+radius])
plt.scatter(p_x, p_y)
plt.axis('equal')
plt.show()
# Out:
# [ 51 132 190 216 116 290 138 230 254 207 276 177 229  70 138  13 320 234
#  142 180  73 200   5  72 300 170 171 305 351 127 351 337  12   9 212 274
#  164  59 293 314 303 298  97  53 251 292 244  45 326 224 270 116  76  17
#  270 128  74 280 105 283 276 226 180 230 173  11  53 162 219  59  96 129
#   71 251 162 161 343 124 354 159 283 240  56 187 199 323 301 116  50 151
#  290  74  46 137 126  65  37 192  84 317 321 326 327 352  56 352  91 234
#   87 337 331 205 106 230 241 233 246 237 322 213 124 337  22 279 239  87
#  329 307  64  11  10 226 136 153 203  56 107  60 312  17 124 236 358 214
#  168  10 354 202 273  43 171  77 247  77 143 242  25  15   8 258 134 177
#  355 111 252 247 275  67 347  96  13 168  48 334  44 228 236 258 130 332
#  358 287  92  64 352 342 325  77  70   4 154 143 284  82 123 156 146  81
#  130 216 163 284 219 172  34  87   5 177 292 191  96 190  72  44 229 122
#    5 318 193 195 117 116 274 280  11 292 127   6 200 339 288 315  70  98
#  322 292  41  77 278 297 172  56  12 284 335 310  53 357 174 249 324  52
#  294  31 111  17 231 339 150 156 132 176  40 104 260 349  89  82 330 207
#  212 222 339 249 275 196 184 336 248 283 278  68  30 307 189 345 214 145
#  116 101  89 246   2 322 142 185  86 348 333   5  55 132 257 179 122 168
#   94 122 351 135 214 220 241 207 187  39 168  20 308 292 135 313  96 291
# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random
# plt.figure(figsize=(8,8))
circle_theta=np.linspace(0, 2*math.pi, 150)
# circle_theta
c_x=100
c_y=100

radius_b=20
radius_a=2*radius_b
X=c_x+radius_a* np.cos(circle_theta)-radius_b* np.sin(circle_theta)
Y=c_y+radius_a* np.cos(circle_theta)+radius_b* np.sin(circle_theta)

#generate points
# p_x=[]
# p_y=[]
# num=np.random.randint(0,360, 1000)
# print(num)

# for i in num:
#   theta_in_radian=math.radians(i)
#   r=np.random.randint(0,radius, 1)
#   p_x.append(c_x + r*np.cos(theta_in_radian))
#   p_y.append(c_y + r*np.sin(theta_in_radian))
# print(len(p_x), len(p_y))

# theta_in_radian=math.radians(45)
# p_x=c_x+10*np.cos(theta_in_radian)
# p_y=c_y+10*np.sin(theta_in_radian)
# print(p_x, p_y)

# plotting
plt.plot(X,Y)
# plt.plot([c_x-radius, c_x+radius], [c_y, c_y])
# plt.plot([c_x, c_x], [c_y-radius, c_y+radius])
# plt.scatter(p_x, p_y)
plt.axis('equal')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
import math
import random
# plt.figure(figsize=(8,8))
circle_theta=np.linspace(0, 2*math.pi, 150)
# circle_theta
c_x=100
c_y=100

radius_b=20
radius_a=2*radius_b

X=c_x+radius_a* np.cos(circle_theta)
Y=c_y+radius_b* np.sin(circle_theta)

#generate points
p_x=[]
p_y=[]
num=np.random.randint(0,360, 200)
print(num)

for i in num:
  theta_in_radian=math.radians(i)
  r_A=np.random.randint(0,radius_a, 1)
  r_B=np.random.randint(0,radius_b, 1)

  p_x.append(c_x+r_A* np.cos(theta_in_radian))
  p_y.append(c_y+r_B* np.sin(theta_in_radian))
print(len(p_x), len(p_y))

# theta_in_radian=math.radians(45)
# p_x=c_x+10*np.cos(theta_in_radian)
# p_y=c_y+10*np.sin(theta_in_radian)
# print(p_x, p_y)

# plotting
plt.plot(X,Y)
plt.plot([c_x-radius_a, c_x+radius_a], [c_y, c_y])
plt.plot([c_x, c_x], [c_y-radius_b, c_y+radius_b])
plt.scatter(p_x, p_y)
#plt.plot([c_x, e_x1], [c_y, e_y1], c='r', linewidth='5')
#plt.plot([c_x, e_x2], [c_y, e_y2], c='g', linewidth='5')
plt.axis('equal')
plt.show()
# Out:
# [ 40  14  52 229 167 250 270 225 244 173 250 281 195 187  26 111 121 224
#  274 211  71 324  94  87 339 144  35 219 272 222 122 212 294 238 330 263
#  311 285  82 353 205 143 320   9 331  29 242 353 326  76 107 134 339  40
#  102 153 346 355 314 322  47  35 329 147 313 200  91  26 265  21  38  10
#   63 208  86 329 236 127 155 149  91 157 169 141 183 345  62  51  43 243
#   17 275  59 190 283  53 322  40 178  54 241  31 298 358 236 302 165 154
#   89 229 295 143 116 253 136 160  73 280 184  96  43 319 237 267 262 251
#  289 134 190 279 244  46 175 112 155  23 223  40  11 228 170  60 339 122
#  173 154 162  76 273  86 328 278 336 290 354 247  18  72 224 228  61 119
#  163 112 261 176 305 232 188 227 354 181 116 204 170 346 240 209 240 153
#   47 319 154 359 106 112 168 301  56 102 188  27 237  82 248 156 276  54
#  321 138]
# 200 200
