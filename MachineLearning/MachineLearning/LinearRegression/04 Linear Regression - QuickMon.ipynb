# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
a=2
b=3
X=np.linspace(-10, 10 ,100)
Y_noisy=a*X+b+0.9*np.random.normal(0,100, 100)
X.shape, Y_noisy.shape
# Out:
# ((100,), (100,))

# %%
plt.scatter(X, Y_noisy, c='r', s=5)
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X=X.reshape(100, 1)
# Y_noisy=Y_noisy(100, 1)

# %%
model=LinearRegression()
model.fit(X, Y_noisy)
model.coef_, a
model.intercept_, b
# Out:
# (0.8297670171202604, 3)

# %%
test_X=np.array([[6],[7]])
test_X.shape
# Out:
# (2, 1)

# %%
y_pred=model.predict(test_X)
Y=a*X+b
Y_predict=model.coef_*X+model.intercept_

# %%
plt.scatter(X, Y_noisy, c='r', s=5)
plt.plot(X, Y, c='k')
plt.scatter(test_X, y_pred, c='b', s=10)
plt.plot(X, Y_predict, c='g')
plt.show()

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("quickMon2.csv")
print(df.head())
# Out:
#                   dateTime    cpuTime  availRamMb  tcpv4TotalConn  \
# 0  11/30/2023 10:52:52.509  54.047116        9251            9933
# 1  11/30/2023 10:53:38.980  39.680763        9245            9883
# 2  11/30/2023 10:54:39.113  38.955606        9207            9832
# 3  11/30/2023 10:55:39.803  36.636897        9202            9850
# 4  11/30/2023 10:56:39.622  37.912277        9220            9932
#
#    tcpV6TotalConn  httpdSize   httpd1Size  httpd1Private  httpd1NPBytes  \
# 0               0    4272128  23136813056    23839506432        7678512
# 1               0    4272128  23143690240    23846383616        8064752
# 2               0    4272128  23163789312    23866806272        7561992
# 3               0    4272128  23170654208    23873957888        7565840
# 4               0    4272128  23185199104    23889031168        7563192
#
#    httpd1Handle  ...  time_wait1912  fin_wait1912  total7077  established7077  \
# ...

# %%
numericColumns = ['cpuTime','availRamMb','tcpV6TotalConn','httpdSize','httpd1Size','httpd1Private','httpd1NPBytes','httpd1Handle','httpd2Size','total1911','established1911','time_wait1911','fin_wait1911','total1912','established1912','time_wait1912','fin_wait1912','total7077','established7077','time_wait7077','fin_wait7077','total7078','established7078','time_wait7078']
print(numericColumns)
# Out:
# ['cpuTime', 'availRamMb', 'tcpV6TotalConn', 'httpdSize', 'httpd1Size', 'httpd1Private', 'httpd1NPBytes', 'httpd1Handle', 'httpd2Size', 'total1911', 'established1911', 'time_wait1911', 'fin_wait1911', 'total1912', 'established1912', 'time_wait1912', 'fin_wait1912', 'total7077', 'established7077', 'time_wait7077', 'fin_wait7077', 'total7078', 'established7078', 'time_wait7078']

# %%
correlationMatrix  = df.loc[:,numericColumns].corr()

# %%
correlationMatrix
# Out:
#                   cpuTime  availRamMb  tcpV6TotalConn  httpdSize  httpd1Size  \
# cpuTime          1.000000    0.433316             NaN        NaN   -0.652400
# availRamMb       0.433316    1.000000             NaN        NaN   -0.892052
# tcpV6TotalConn        NaN         NaN             NaN        NaN         NaN
# httpdSize             NaN         NaN             NaN        NaN         NaN
# httpd1Size      -0.652400   -0.892052             NaN        NaN    1.000000
# httpd1Private   -0.652346   -0.892074             NaN        NaN    1.000000
# httpd1NPBytes    0.569014    0.666963             NaN        NaN   -0.840685
# httpd1Handle     0.574123    0.674530             NaN        NaN   -0.845565
# httpd2Size            NaN         NaN             NaN        NaN         NaN
# total1911        0.136712   -0.018363             NaN        NaN   -0.096195
# established1911  0.042914   -0.287802             NaN        NaN    0.140387
# ...

# %%
boston.target
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %%
import numpy as np
from sklearn.datasets import fetch_openml
boston=fetch_openml(name='boston', version=1, as_frame=True)
boston.data
# Out:
#         CRIM    ZN  INDUS CHAS    NOX     RM   AGE     DIS RAD    TAX  \
# 0    0.00632  18.0   2.31    0  0.538  6.575  65.2  4.0900   1  296.0
# 1    0.02731   0.0   7.07    0  0.469  6.421  78.9  4.9671   2  242.0
# 2    0.02729   0.0   7.07    0  0.469  7.185  61.1  4.9671   2  242.0
# 3    0.03237   0.0   2.18    0  0.458  6.998  45.8  6.0622   3  222.0
# 4    0.06905   0.0   2.18    0  0.458  7.147  54.2  6.0622   3  222.0
# ..       ...   ...    ...  ...    ...    ...   ...     ...  ..    ...
# 501  0.06263   0.0  11.93    0  0.573  6.593  69.1  2.4786   1  273.0
# 502  0.04527   0.0  11.93    0  0.573  6.120  76.7  2.2875   1  273.0
# 503  0.06076   0.0  11.93    0  0.573  6.976  91.0  2.1675   1  273.0
# 504  0.10959   0.0  11.93    0  0.573  6.794  89.3  2.3889   1  273.0
# 505  0.04741   0.0  11.93    0  0.573  6.030  80.8  2.5050   1  273.0
#
#      PTRATIO       B  LSTAT
# 0       15.3  396.90   4.98
# 1       17.8  396.90   9.14
# 2       17.8  392.83   4.03
# ...

# %%
boston.target
df=boston.data.copy()
df['Price']=boston.target
df
boston.feature_names
print(boston.DESCR)
# Out:
# **Author**:
# **Source**: Unknown - Date unknown
# **Please cite**:
#
# The Boston house-price data of Harrison, D. and Rubinfeld, D.L. 'Hedonic
# prices and the demand for clean air', J. Environ. Economics & Management,
# vol.5, 81-102, 1978.   Used in Belsley, Kuh & Welsch, 'Regression diagnostics
# ...', Wiley, 1980.   N.B. Various transformations are used in the table on
# pages 244-261 of the latter.
# Variables in order:
# CRIM     per capita crime rate by town
# ZN       proportion of residential land zoned for lots over 25,000 sq.ft.
# INDUS    proportion of non-retail business acres per town
# CHAS     Charles River dummy variable (= 1 if tract bounds river; 0 otherwise)
# NOX      nitric oxides concentration (parts per 10 million)
# RM       average number of rooms per dwelling
# AGE      proportion of owner-occupied units built prior to 1940
# DIS      weighted distances to five Boston employment centres
# RAD      index of accessibility to radial highways
# ...

# %%
df.describe()
df[df.isnull().any(axis=1)]
corr=df.corr()
corr
# Out:
#              CRIM        ZN     INDUS       NOX        RM       AGE       DIS  \
# CRIM     1.000000 -0.200469  0.406583  0.420972 -0.219247  0.352734 -0.379670
# ZN      -0.200469  1.000000 -0.533828 -0.516604  0.311991 -0.569537  0.664408
# INDUS    0.406583 -0.533828  1.000000  0.763651 -0.391676  0.644779 -0.708027
# NOX      0.420972 -0.516604  0.763651  1.000000 -0.302188  0.731470 -0.769230
# RM      -0.219247  0.311991 -0.391676 -0.302188  1.000000 -0.240265  0.205246
# AGE      0.352734 -0.569537  0.644779  0.731470 -0.240265  1.000000 -0.747881
# DIS     -0.379670  0.664408 -0.708027 -0.769230  0.205246 -0.747881  1.000000
# TAX      0.582764 -0.314563  0.720760  0.668023 -0.292048  0.506456 -0.534432
# PTRATIO  0.289946 -0.391679  0.383248  0.188933 -0.355501  0.261515 -0.232471
# B       -0.385064  0.175520 -0.356977 -0.380051  0.128069 -0.273534  0.291512
# LSTAT    0.455621 -0.412995  0.603800  0.590879 -0.613808  0.602339 -0.496996
# ...

# %%
import seaborn as sns
plt.figure(figsize=(10,10))
sns.heatmap(corr, cbar=True, square=True, fmt='0.1f', cmap='Greens',annot=True, annot_kws={'size':15})
plt.show()

# %%
X=boston.data
Y=boston.target

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test=train_test_split(X,Y, test_size=0.3, random_state=4)
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((354, 13), (152, 13), (354,), (152,))

# %%
from sklearn.linear_model import LinearRegression
model_boston=LinearRegression()
model_boston.fit(X_train, Y_train)
model_boston.coef_
# Out:
# C:\Vipul\Anaconda\lib\site-packages\sklearn\utils\validation.py:964: FutureWarning: Arrays of bytes/strings is being converted to decimal numbers if dtype='numeric'. This behavior is deprecated in 0.24 and will be removed in 1.1 (renaming of 0.26). Please convert your data to numeric values explicitly instead.
#   X = check_array(
# array([-1.22569795e-01,  5.56776996e-02, -8.83428230e-03,  4.69344849e+00,
#        -1.44357828e+01,  3.28008033e+00, -3.44778157e-03, -1.55214419e+00,
#         3.26249618e-01, -1.40665500e-02, -8.03274915e-01,  9.35368715e-03,
#        -5.23477529e-01])

# %%
Coff=pd.DataFrame([X_train.columns, model_boston.coef_]).T
Coff
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14096\474857576.py in <module>
# ----> 1 Coff=pd.DataFrame([X_train.columns, model_boston.coef_]).T
#       2 Coff
#
# NameError: name 'pd' is not defined

# %%
model_boston.intercept_
# Out:
# 36.357041376595205

# %%
X_new=np.array([[0.00632,	38.0,	5.31,	1,	0.508,9.575,	45.2,	4.0900,	1,	296.0,	15.3,	396.90,	4.98]])
model_boston.predict(X_new)
Y_predict=model_boston.predict(X_test.values)
# Out:
# C:\Vipul\Anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# C:\Vipul\Anaconda\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
from sklearn import metrics
metrics.mean_squared_error(Y_test, Y_predict)
metrics.mean_absolute_error(Y_test, Y_predict)
np.sqrt(metrics.mean_squared_error(Y_test, Y_predict))
# Out:
# 5.482152251362974

# %%
#https://scikit-learn.org/stable/modules/classes.html#module-sklearn.datasets
from sklearn.datasets import fetch_california_housing
california_housing=fetch_california_housing(as_frame=True)
df=california_housing.data.copy()
df['Price']=california_housing.target
df
# Out:
#        MedInc  HouseAge  AveRooms  AveBedrms  Population  AveOccup  Latitude  \
# 0      8.3252      41.0  6.984127   1.023810       322.0  2.555556     37.88
# 1      8.3014      21.0  6.238137   0.971880      2401.0  2.109842     37.86
# 2      7.2574      52.0  8.288136   1.073446       496.0  2.802260     37.85
# 3      5.6431      52.0  5.817352   1.073059       558.0  2.547945     37.85
# 4      3.8462      52.0  6.281853   1.081081       565.0  2.181467     37.85
# ...       ...       ...       ...        ...         ...       ...       ...
# 20635  1.5603      25.0  5.045455   1.133333       845.0  2.560606     39.48
# 20636  2.5568      18.0  6.114035   1.315789       356.0  3.122807     39.49
# 20637  1.7000      17.0  5.205543   1.120092      1007.0  2.325635     39.43
# 20638  1.8672      18.0  5.329513   1.171920       741.0  2.123209     39.43
# 20639  2.3886      16.0  5.254717   1.162264      1387.0  2.616981     39.37
#
#        Longitude  Price
# ...

# %%
import sklearn
sklearn.__version__
# Out:
# '1.0.2'
