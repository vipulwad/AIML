# %%
import matplotlib.pyplot as plt

# unused but required import for doing 3d projections with matplotlib < 3.2
import mpl_toolkits.mplot3d  # noqa: F401
import numpy as np

from sklearn import datasets, decomposition
from sklearn.decomposition import PCA
from mpl_toolkits.mplot3d import Axes3D

# %%
np.random.seed(5)

iris = datasets.load_iris()
X = iris.data
y = iris.target

fig = plt.figure(1, figsize=(4, 3))
plt.clf()

ax = fig.add_subplot(111, projection="3d", elev=48, azim=134)
ax.set_position([0, 0, 0.95, 1])

# %%
plt.cla()
pca = decomposition.PCA(n_components=3)
pca.fit(X)
X = pca.transform(X)

for name, label in [("Setosa", 0), ("Versicolour", 1), ("Virginica", 2)]:
    ax.text3D(
        X[y == label, 0].mean(),
        X[y == label, 1].mean() + 1.5,
        X[y == label, 2].mean(),
        name,
        horizontalalignment="center",
        bbox=dict(alpha=0.5, edgecolor="w", facecolor="w"),
    )

# %%
# Reorder the labels to have colors matching the cluster results
y = np.choose(y, [1, 2, 0]).astype(float)
ax.scatter(X[:, 0], X[:, 1], X[:, 2], c=y, cmap=plt.cm.nipy_spectral, edgecolor="k")

ax.xaxis.set_ticklabels([])
ax.yaxis.set_ticklabels([])
ax.zaxis.set_ticklabels([])

plt.show()

# %% [markdown]
# # Redcution of IRIS DATA SET

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.decomposition import PCA

# %%
# Load the Iris dataset
iris = load_iris()
X = iris.data
y = iris.target

# %%
# Apply PCA for dimensionality reduction
pca = PCA(n_components=2)
reduced_data = pca.fit_transform(X)

# %%
# Plot the reduced data in 2D
plt.figure(figsize=(8, 6))
for target, target_name in enumerate(iris.target_names):
    plt.scatter(reduced_data[y == target, 0], reduced_data[y == target, 1], label=target_name)

plt.title('Iris Dataset - PCA Dimensionality Reduction')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.legend()
plt.grid(True)
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_breast_cancer
from sklearn.decomposition import PCA

# %%
# Load the Iris dataset
iris = load_breast_cancer()
X = iris.data
y = iris.target
X.shape
# Out:
# (569, 30)

# %%
# Apply PCA for dimensionality reduction
pca = PCA(n_components=3)
reduced_data = pca.fit_transform(X)

reduced_data
# Out:
# array([[1160.1425737 , -293.91754364,   48.57839763],
#        [1269.12244319,   15.63018184,  -35.39453423],
#        [ 995.79388896,   39.15674324,   -1.70975298],
#        ...,
#        [ 314.50175618,   47.55352518,  -10.44240718],
#        [1124.85811531,   34.12922497,  -19.74208742],
#        [-771.52762188,  -88.64310636,   23.88903189]])

# %%
# Plot the reduced data in 2D
plt.figure()
plt.axes(projection='3d')
for target, target_name in enumerate(iris.target_names):
    plt.scatter(reduced_data[y == target, 0], reduced_data[y == target, 1], reduced_data[y == target, 2], label=target_name)

plt.title('Iris Dataset - PCA Dimensionality Reduction')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')#plt.zlabel('Principal Component 3')
plt.legend()
plt.grid(True)
plt.show(block=False)
