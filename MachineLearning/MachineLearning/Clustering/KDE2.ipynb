# %% [markdown]
# # Unsupervised Learning
#
# * Parametric Clustering Algorithms:
#
#   **Assumption**: Parametric algorithms make specific assumptions about the form of the underlying data distribution.
#
#   **Example**: Gaussian Mixture Models (GMM), K-Means.
#
#   **Characteristic**: Assumes clusters follow a particular parametric distribution (e.g., Gaussian) and aims to estimate the parameters of that distribution.
#
# * Generic Clustering Algorithms:
#
#   **Assumption**: Nonparametric algorithms make minimal assumptions about the underlying data distribution and often do not require specifying the number of clusters in advance.
#
#   **Example**: Mean Shift.
#
#   **Characteristic**: Particularly useful when the number of clusters is unknown or when dealing with complex, irregularly shaped clusters. They adapt to the inherent structure of the data.

# %% [markdown]
# ## Key Differences
#
# * Distribution Assumptions:
#
#   * Parametric: Assumes a specific parametric form for the underlying data distribution.
#   * Generic: Makes minimal assumptions about the data distribution and often does not require specifying the number of clusters.
# * Flexibility:
#
#   * Parametric: Less flexible due to strict distribution assumptions.
#   * Generic:  Highly flexible, adapting to the data structure without strong assumptions.
#
# * Number of Clusters:
#
#   * Parametric: Often requires specifying the number of clusters in advance.
#   * Generic: Often does not require specifying the number of clusters, allowing the algorithm to discover the structure autonomously.
#
# * Shape of Clusters:
#
#  * Parametric: Assumes a specific shape for clusters (e.g., spherical in K-Means, Gaussian in GMM).
#  * Generic: Adapts to various shapes and sizes of clusters without assuming a particular form.

# %% [markdown]
# ## Summary
# In summary, parametric clustering algorithms make strong assumptions about the underlying data distribution, generic clustering make minimal assumptions and often do not require specifying the number of clusters in advance. The choice of algorithm depends on the characteristics of the data and the goals of the analysis.

# %% [markdown]
# ## What is estimation theory?
# Estimation theory is a branch of statistics that deals with the process of estimating the characteristics of a population based on a sample of data drawn from that population. The goal is to make informed predictions or inferences about the population parameters using statistical methods.
#
# or Estimation theory involves methods for estimating unknown parameters or characteristics of a population based on a sample of data. This is crucial in statistics, where we often deal with incomplete information and want to infer characteristics of a larger group based on a smaller group that we observe.
#
# * Parametric Estimation:
#
#   * Assumption: Assumes that the data follows a specific distribution or model. It specifies the form of the distribution and the parameters that characterize it.
#
#   * Example: Assuming the data follows a normal distribution, you estimate the mean and standard deviation as parameters.
#
#   * Flexibility: More rigid, as it requires a strong assumption about the data distribution. The accuracy of the estimation depends on the correctness of the assumed distribution.
#
#   * Common Methods: Maximum Likelihood Estimation (MLE).
#
# * Nonparametric Estimation:
#
#   * Assumption: Makes fewer or no assumptions about the specific form of the underlying distribution. It focuses on estimating functions rather than parameters.
#
#   * Example: Using the median or kernel density estimation without assuming a specific distribution.
#
#   * Flexibility: More flexible, especially in situations where the true data distribution is unknown or difficult to specify. Can handle a wide range of data distributions.
#
#   * Common Methods: Kernel Density Estimation, Median, Rank-based methods.

# %% [markdown]
# # Parametric estimation
# Parametric estimation involves making specific assumptions about the underlying distribution of the data and then using observed data to estimate the parameters of that assumed distribution.
# 1. Choose a Model : Select a specific probability distribution or statistical model that you believe represents the data well. Common distributions include normal (Gaussian), exponential, Poisson, etc.
# 2. Define Parameters : Identify the parameters of the chosen distribution. Parameters are the characteristics that determine the shape and location of the distribution. For example, in a normal distribution, parameters include the mean and standard deviation.
# 3. Collect Data : Gather a sample of data from the population of interest. The sample should be representative of the larger population.
# 4. Estimate Parameters : Use the collected data to estimate the parameters of the chosen distribution. The estimation process aims to find the values for the parameters that make the assumed distribution most likely to have produced the observed data.

# %% [markdown]
# # Nonparametric estimation
#
# Nonparametric estimation involves estimating characteristics of a population without making specific assumptions about the underlying probability distribution. nonparametric estimation is typically done:
#
# 1. Collect Data:
#
#   Gather a sample of data from the population of interest. The sample should be representative of the larger population.
#
# 2. Select a Nonparametric Method:
#
#   Choose a nonparametric method based on the specific characteristics you want to estimate. Common nonparametric methods include kernel density estimation, median estimation, rank-based methods, etc.

# %% [markdown]
# ## Kernel Density Estimation (KDE)
# 1. Kernel Selection:
#
#   Choose a kernel function. The kernel determines the shape of the smoothing function around each data point.
# 2. Bandwidth Selection:
#
#   Select a bandwidth parameter. The bandwidth controls the width of the kernel and influences the smoothness of the estimated density.
#
# 3. Smooth the Data:
#
#   Place a kernel around each data point and sum them up to create a smooth estimate of the underlying probability density function.
#   The formula for the kernel density estimate at a point x might look like this
#
#   $f(x)= \frac{1}{nh} \sum_{i=1}^{n} K \left( \frac{x-x_i}{h} \right)$
#
# 4. Sum Kernel Contributions:
#
#   Sum up the contributions from all data points to create the overall KDE.
#
# 5. Mode finding :
#
#   Calculate the numerical derivative of the KDE curve and identifying points where the derivative changes from positive to negative. This technique is used to locate local maxima, which correspond to peaks in the KDE curve and, in the context of probability density estimation, represent modes in the distribution.

# %% [markdown]
# ### KDE in 1D data

# %%
import numpy as np
import matplotlib.pyplot as plt
# Create a synthetic dataset (you can replace this with your own data)
np.random.seed(42)

# %%
np.random.normal(10, 3, (10,2,3))
# Out:
# array([[[11.49014246,  9.5852071 , 11.94306561],
#         [14.56908957,  9.29753988,  9.29758913]],
#
#        [[14.73763845, 12.30230419,  8.59157684],
#         [11.62768013,  8.60974692,  8.60281074]],
#
#        [[10.72588681,  4.26015927,  4.8252465 ],
#         [ 8.31313741,  6.96150664, 10.942742  ]],
#
#        [[ 7.27592777,  5.7630889 , 14.39694631],
#         [ 9.3226711 , 10.20258461,  5.72575544]],
#
#        [[ 8.36685183, 10.33276777,  6.54701927],
#         [11.12709406,  8.19808393,  9.12491875]],
#
#        [[ 8.19488016, 15.55683455,  9.95950833],
#         [ 6.82686721, 12.46763474,  6.33746905]],
#
#        [[10.62659079,  4.12098963,  6.01544185],
#         [10.59058371, 12.21539974, 10.51410484]],
#
#        [[ 9.65305515,  9.09668891,  5.56443403],
#         [ 7.84046737,  8.61808369, 13.17136668]],
#
#        [[11.03085487,  4.71087953, 10.97225191],
#         [ 8.84475316,  7.969234  , 11.83502887]],
#
#        [[13.09299857, 12.79384036,  7.48234743],
#         [ 9.07236287, 10.99379029, 12.92663538]]])

# %%
data = np.concatenate([np.random.normal(0, 1, 30), np.random.normal(4, 1, 30), np.random.normal(4, 6, 30)])
print(data.shape)
# Reshape the data to fit the scikit-learn API
data = data.reshape(-1, 1)
print(data.shape)
# Out:
# (90,)
# (90, 1)

# %%
# Plot the original data
plt.hist(data, bins=30, density=True, alpha=0.7, color='blue', label='Histogram')
plt.scatter(data, np.zeros_like(data), marker='x', color='red')
plt.xlabel('Data Points')
plt.ylabel('Counts')
plt.legend()
plt.show()

# %%
from scipy.stats import norm
# Generate points for plotting
x_plot = np.linspace(min(data), max(data), 1000).reshape(-1, 1)
for ix,point in enumerate(data):
    y = norm.pdf(x_plot, loc=point, scale=0.1)  # Adjust the scale as needed
    plt.scatter(point, 0)
    plt.plot(x_plot, y, linestyle='dashed', linewidth=0.5, color='black')
    # if ix==3:
    #   break

# %%
from sklearn.neighbors import KernelDensity
# Create a KDE model
# kernel{‘gaussian’, ‘tophat’, ‘epanechnikov’, ‘exponential’, ‘linear’, ‘cosine’}, default=’gaussian’
# bandwidth= float or {“scott”, “silverman”}, default=1.0
# The bandwidth of the kernel. If bandwidth is a float, it defines the bandwidth of the kernel. If bandwidth is a string, one of the estimation methods is implemented.
kde = KernelDensity(bandwidth=0.75, kernel='gaussian')
kde.fit(data)
# Out:
# KernelDensity(bandwidth=0.75)

# %%
# Generate points for plotting
x_plot = np.linspace(min(data), max(data), 1000).reshape(-1, 1)

# Evaluate the KDE model on the generated points
log_dens = kde.score_samples(x_plot)
# Plot the KDE estimate
plt.plot(x_plot, np.exp(log_dens), color='red', label='Kernel Density Estimate')


plt.title('KDE for 1D Data with Modes Identified')
plt.xlabel('Data Points')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
# Find peaks (modes) using a simple derivative approach
# 1. Calculate the Numerical Derivative
# Use the np.diff function to calculate the differences between consecutive elements
# in the array representing the KDE curve. This effectively computes a
# numerical approximation of the derivative.

derivative = np.diff(np.exp(log_dens))
print(derivative)
# Out:
# [ 1.90183095e-04  1.85853134e-04  1.81474667e-04  1.77067297e-04
#   1.72650714e-04  1.68244589e-04  1.63868472e-04  1.59541679e-04
#   1.55283187e-04  1.51111533e-04  1.47044706e-04  1.43100054e-04
#   1.39294180e-04  1.35642858e-04  1.32160942e-04  1.28862285e-04
#   1.25759665e-04  1.22864715e-04  1.20187863e-04  1.17738276e-04
#   1.15523814e-04  1.13550993e-04  1.11824952e-04  1.10349434e-04
#   1.09126772e-04  1.08157886e-04  1.07442284e-04  1.06978079e-04
#   1.06762008e-04  1.06789464e-04  1.07054533e-04  1.07550038e-04
#   1.08267596e-04  1.09197675e-04  1.10329666e-04  1.11651948e-04
#   1.13151978e-04  1.14816366e-04  1.16630969e-04  1.18580981e-04
#   1.20651034e-04  1.22825293e-04  1.25087556e-04  1.27421365e-04
#   1.29810100e-04  1.32237091e-04  1.34685718e-04  1.37139515e-04
#   1.39582272e-04  1.41998132e-04  1.44371692e-04  1.46688092e-04
#   1.48933107e-04  1.51093231e-04  1.53155761e-04  1.55108868e-04
#   1.56941669e-04  1.58644293e-04  1.60207938e-04  1.61624919e-04
#   1.62888718e-04  1.63994020e-04  1.64936742e-04  1.65714060e-04
#   1.66324421e-04  1.66767556e-04  1.67044478e-04  1.67157480e-04
#   1.67110116e-04  1.66907189e-04  1.66554716e-04  1.66059899e-04
#   1.65431079e-04  1.64677697e-04  1.63810233e-04  1.62840151e-04
#   1.61779834e-04  1.60642514e-04  1.59442201e-04  1.58193602e-04
#   1.56912039e-04  1.55613368e-04  1.54313888e-04  1.53030252e-04
#   1.51779378e-04  1.50578355e-04  1.49444351e-04  1.48394518e-04
#   1.47445906e-04  1.46615368e-04  1.45919470e-04  1.45374410e-04
#   1.44995931e-04  1.44799244e-04  1.44798947e-04  1.45008961e-04
#   1.45442459e-04  1.46111807e-04  1.47028509e-04  1.48203158e-04
#   1.49645396e-04  1.51363876e-04  1.53366234e-04  1.55659071e-04
#   1.58247936e-04  1.61137323e-04  1.64330670e-04  1.67830368e-04
#   1.71637778e-04  1.75753253e-04  1.80176173e-04  1.84904973e-04
#   1.89937194e-04  1.95269531e-04  2.00897884e-04  2.06817424e-04
#   2.13022651e-04  2.19507470e-04  2.26265258e-04  2.33288939e-04
#   2.40571064e-04  2.48103890e-04  2.55879454e-04  2.63889660e-04
#   2.72126352e-04  2.80581395e-04  2.89246750e-04  2.98114545e-04
#   3.07177147e-04  3.16427226e-04  3.25857815e-04  3.35462367e-04
#   3.45234803e-04  3.55169557e-04  3.65261611e-04  3.75506521e-04
#   3.85900447e-04  3.96440157e-04  4.07123039e-04  4.17947095e-04
#   4.28910930e-04  4.40013735e-04  4.51255256e-04  4.62635757e-04
#   4.74155979e-04  4.85817085e-04  4.97620602e-04  5.09568351e-04
#   5.21662375e-04  5.33904859e-04  5.46298044e-04  5.58844134e-04
#   5.71545203e-04  5.84403096e-04  5.97419324e-04  6.10594961e-04
#   6.23930539e-04  6.37425940e-04  6.51080290e-04  6.64891854e-04
#   6.78857933e-04  6.92974764e-04  7.07237422e-04  7.21639728e-04
#   7.36174166e-04  7.50831796e-04  7.65602186e-04  7.80473343e-04
#   7.95431660e-04  8.10461861e-04  8.25546969e-04  8.40668274e-04
#   8.55805316e-04  8.70935881e-04  8.86036001e-04  9.01079977e-04
#   9.16040401e-04  9.30888203e-04  9.45592699e-04  9.60121656e-04
#   9.74441374e-04  9.88516766e-04  1.00231146e-03  1.01578792e-03
#   1.02890755e-03  1.04163083e-03  1.05391745e-03  1.06572650e-03
#   1.07701655e-03  1.08774589e-03  1.09787263e-03  1.10735495e-03
#   1.11615119e-03  1.12422011e-03  1.13152104e-03  1.13801404e-03
#   1.14366014e-03  1.14842146e-03  1.15226146e-03  1.15514502e-03
#   1.15703873e-03  1.15791095e-03  1.15773204e-03  1.15647446e-03
#   1.15411296e-03  1.15062467e-03  1.14598927e-03  1.14018904e-03
#   1.13320901e-03  1.12503703e-03  1.11566386e-03  1.10508317e-03
#   1.09329167e-03  1.08028909e-03  1.06607821e-03  1.05066487e-03
#   1.03405796e-03  1.01626939e-03  9.97314039e-04  9.77209751e-04
#   9.55977223e-04  9.33639953e-04  9.10224143e-04  8.85758608e-04
#   8.60274658e-04  8.33805986e-04  8.06388536e-04  7.78060367e-04
#   7.48861514e-04  7.18833834e-04  6.88020857e-04  6.56467625e-04
#   6.24220533e-04  5.91327164e-04  5.57836127e-04  5.23796890e-04
#   4.89259622e-04  4.54275026e-04  4.18894182e-04  3.83168392e-04
#   3.47149027e-04  3.10887382e-04  2.74434536e-04  2.37841213e-04
#   2.01157658e-04  1.64433513e-04  1.27717704e-04  9.10583350e-05
#   5.45025918e-05  1.80966490e-05 -1.81144099e-05 -5.40866657e-05
#  -8.97774288e-05 -1.25145296e-04 -1.60150198e-04 -1.94753442e-04
#  -2.28917745e-04 -2.62607256e-04 -2.95787580e-04 -3.28425784e-04
#  -3.60490409e-04 -3.91951466e-04 -4.22780430e-04 -4.52950230e-04
#  -4.82435235e-04 -5.11211232e-04 -5.39255405e-04 -5.66546305e-04
#  -5.93063826e-04 -6.18789164e-04 -6.43704794e-04 -6.67794424e-04
#  -6.91042964e-04 -7.13436486e-04 -7.34962185e-04 -7.55608339e-04
#  -7.75364271e-04 -7.94220308e-04 -8.12167742e-04 -8.29198793e-04
#  -8.45306566e-04 -8.60485019e-04 -8.74728923e-04 -8.88033826e-04
#  -9.00396016e-04 -9.11812492e-04 -9.22280924e-04 -9.31799625e-04
#  -9.40367516e-04 -9.47984095e-04 -9.54649411e-04 -9.60364028e-04
#  -9.65128999e-04 -9.68945837e-04 -9.71816487e-04 -9.73743298e-04
#  -9.74728996e-04 -9.74776654e-04 -9.73889670e-04 -9.72071736e-04
#  -9.69326816e-04 -9.65659112e-04 -9.61073048e-04 -9.55573237e-04
#  -9.49164458e-04 -9.41851631e-04 -9.33639792e-04 -9.24534070e-04
#  -9.14539663e-04 -9.03661816e-04 -8.91905802e-04 -8.79276897e-04
#  -8.65780370e-04 -8.51421460e-04 -8.36205363e-04 -8.20137223e-04
#  -8.03222122e-04 -7.85465074e-04 -7.66871019e-04 -7.47444831e-04
#  -7.27191317e-04 -7.06115230e-04 -6.84221282e-04 -6.61514163e-04
#  -6.37998567e-04 -6.13679223e-04 -5.88560927e-04 -5.62648591e-04
#  -5.35947286e-04 -5.08462302e-04 -4.80199208e-04 -4.51163920e-04
#  -4.21362783e-04 -3.90802646e-04 -3.59490956e-04 -3.27435857e-04
#  -2.94646285e-04 -2.61132086e-04 -2.26904123e-04 -1.91974403e-04
#  -1.56356196e-04 -1.20064169e-04 -8.31145130e-05 -4.55250860e-05
#  -7.31554415e-06  3.14925168e-05  7.08754240e-05  1.10807290e-04
#   1.51259877e-04  1.92202467e-04  2.33601733e-04  2.75421618e-04
#   3.17623223e-04  3.60164700e-04  4.03001159e-04  4.46084583e-04
#   4.89363759e-04  5.32784222e-04  5.76288212e-04  6.19814653e-04
#   6.63299146e-04  7.06673985e-04  7.49868188e-04  7.92807558e-04
#   8.35414753e-04  8.77609398e-04  9.19308201e-04  9.60425106e-04
#   1.00087147e-03  1.04055625e-03  1.07938625e-03  1.11726634e-03
#   1.15409974e-03  1.18978833e-03  1.22423294e-03  1.25733372e-03
#   1.28899049e-03  1.31910308e-03  1.34757181e-03  1.37429782e-03
#   1.39918354e-03  1.42213314e-03  1.44305295e-03  1.46185190e-03
#   1.47844204e-03  1.49273894e-03  1.50466219e-03  1.51413583e-03
#   1.52108881e-03  1.52545544e-03  1.52717579e-03  1.52619612e-03
#   1.52246928e-03  1.51595506e-03  1.50662052e-03  1.49444037e-03
#   1.47939717e-03  1.46148168e-03  1.44069300e-03  1.41703880e-03
#   1.39053545e-03  1.36120811e-03  1.32909084e-03  1.29422656e-03
#   1.25666706e-03  1.21647293e-03  1.17371344e-03  1.12846637e-03
#   1.08081783e-03  1.03086200e-03  9.78700825e-04  9.24443717e-04
#   8.68207153e-04  8.10114275e-04  7.50294443e-04  6.88882751e-04
#   6.26019513e-04  5.61849725e-04  4.96522491e-04  4.30190441e-04
#   3.63009114e-04  2.95136337e-04  2.26731591e-04  1.57955360e-04
#   8.89684892e-05  1.99315289e-05 -4.89959066e-05 -1.17655781e-04
#  -1.85892261e-04 -2.53552334e-04 -3.20486400e-04 -3.86548846e-04
#  -4.51598597e-04 -5.15499635e-04 -5.78121489e-04 -6.39339694e-04
#  -6.99036209e-04 -7.57099806e-04 -8.13426407e-04 -8.67919388e-04
#  -9.20489842e-04 -9.71056792e-04 -1.01954736e-03 -1.06589690e-03
#  -1.11004909e-03 -1.15195594e-03 -1.19157781e-03 -1.22888337e-03
#  -1.26384950e-03 -1.29646113e-03 -1.32671114e-03 -1.35460010e-03
#  -1.38013604e-03 -1.40333419e-03 -1.42421667e-03 -1.44281218e-03
#  -1.45915561e-03 -1.47328771e-03 -1.48525467e-03 -1.49510771e-03
#  -1.50290267e-03 -1.50869959e-03 -1.51256225e-03 -1.51455776e-03
#  -1.51475608e-03 -1.51322963e-03 -1.51005282e-03 -1.50530165e-03
#  -1.49905328e-03 -1.49138566e-03 -1.48237709e-03 -1.47210592e-03
#  -1.46065012e-03 -1.44808703e-03 -1.43449299e-03 -1.41994310e-03
#  -1.40451091e-03 -1.38826823e-03 -1.37128489e-03 -1.35362855e-03
#  -1.33536456e-03 -1.31655579e-03 -1.29726255e-03 -1.27754249e-03
#  -1.25745053e-03 -1.23703881e-03 -1.21635672e-03 -1.19545083e-03
#  -1.17436497e-03 -1.15314025e-03 -1.13181508e-03 -1.11042531e-03
#  -1.08900428e-03 -1.06758289e-03 -1.04618977e-03 -1.02485133e-03
#  -1.00359195e-03 -9.82434047e-04 -9.61398248e-04 -9.40503515e-04
#  -9.19767277e-04 -8.99205566e-04 -8.78833154e-04 -8.58663676e-04
#  -8.38709761e-04 -8.18983147e-04 -7.99494792e-04 -7.80254982e-04
#  -7.61273423e-04 -7.42559331e-04 -7.24121505e-04 -7.05968397e-04
#  -6.88108166e-04 -6.70548728e-04 -6.53297784e-04 -6.36362853e-04
#  -6.19751281e-04 -6.03470247e-04 -5.87526757e-04 -5.71927631e-04
#  -5.56679481e-04 -5.41788675e-04 -5.27261305e-04 -5.13103138e-04
#  -4.99319568e-04 -4.85915560e-04 -4.72895592e-04 -4.60263596e-04
#  -4.48022887e-04 -4.36176109e-04 -4.24725162e-04 -4.13671147e-04
#  -4.03014299e-04 -3.92753930e-04 -3.82888379e-04 -3.73414957e-04
#  -3.64329910e-04 -3.55628374e-04 -3.47304351e-04 -3.39350681e-04
#  -3.31759033e-04 -3.24519892e-04 -3.17622570e-04 -3.11055210e-04
#  -3.04804816e-04 -2.98857279e-04 -2.93197420e-04 -2.87809045e-04
#  -2.82675000e-04 -2.77777246e-04 -2.73096937e-04 -2.68614509e-04
#  -2.64309776e-04 -2.60162036e-04 -2.56150181e-04 -2.52252817e-04
#  -2.48448387e-04 -2.44715301e-04 -2.41032069e-04 -2.37377436e-04
#  -2.33730521e-04 -2.30070960e-04 -2.26379041e-04 -2.22635847e-04
#  -2.18823391e-04 -2.14924753e-04 -2.10924208e-04 -2.06807351e-04
#  -2.02561221e-04 -1.98174407e-04 -1.93637157e-04 -1.88941469e-04
#  -1.84081183e-04 -1.79052047e-04 -1.73851787e-04 -1.68480156e-04
#  -1.62938972e-04 -1.57232143e-04 -1.51365680e-04 -1.45347690e-04
#  -1.39188365e-04 -1.32899946e-04 -1.26496679e-04 -1.19994754e-04
#  -1.13412230e-04 -1.06768945e-04 -1.00086415e-04 -9.33877193e-05
#  -8.66973699e-05 -8.00411723e-05 -7.34460743e-05 -6.69400049e-05
#  -6.05517029e-05 -5.43105388e-05 -4.82463287e-05 -4.23891424e-05
#  -3.67691076e-05 -3.14162101e-05 -2.63600929e-05 -2.16298538e-05
#  -1.72538447e-05 -1.32594734e-05 -9.67300785e-06 -6.51938731e-06
#  -3.82203858e-06 -1.60270089e-06  1.18740332e-07  1.32440916e-06
#   1.99858338e-06  2.12782595e-06  1.70110280e-06  7.09886007e-07
#  -8.51758444e-07 -2.98709900e-06 -5.69668362e-06 -8.97830194e-06
#  -1.28269650e-05 -1.72349027e-05 -2.21915787e-05 -2.76837236e-05
#  -3.36953849e-05 -4.02079946e-05 -4.72004535e-05 -5.46492312e-05
#  -6.25284818e-05 -7.08101742e-05 -7.94642358e-05 -8.84587088e-05
#  -9.77599184e-05 -1.07332650e-04 -1.17140339e-04 -1.27145259e-04
#  -1.37308732e-04 -1.47591327e-04 -1.57953069e-04 -1.68353654e-04
#  -1.78752660e-04 -1.89109750e-04 -1.99384890e-04 -2.09538544e-04
#  -2.19531876e-04 -2.29326944e-04 -2.38886879e-04 -2.48176062e-04
#  -2.57160290e-04 -2.65806931e-04 -2.74085059e-04 -2.81965592e-04
#  -2.89421402e-04 -2.96427420e-04 -3.02960718e-04 -3.09000592e-04
#  -3.14528609e-04 -3.19528656e-04 -3.23986969e-04 -3.27892142e-04
#  -3.31235129e-04 -3.34009229e-04 -3.36210054e-04 -3.37835490e-04
#  -3.38885643e-04 -3.39362769e-04 -3.39271201e-04 -3.38617259e-04
#  -3.37409156e-04 -3.35656892e-04 -3.33372143e-04 -3.30568142e-04
#  -3.27259558e-04 -3.23462369e-04 -3.19193730e-04 -3.14471843e-04
#  -3.09315822e-04 -3.03745563e-04 -2.97781610e-04 -2.91445026e-04
#  -2.84757263e-04 -2.77740045e-04 -2.70415242e-04 -2.62804759e-04
#  -2.54930427e-04 -2.46813902e-04 -2.38476569e-04 -2.29939451e-04
#  -2.21223134e-04 -2.12347691e-04 -2.03332616e-04 -1.94196770e-04
#  -1.84958333e-04 -1.75634761e-04 -1.66242757e-04 -1.56798247e-04
#  -1.47316360e-04 -1.37811424e-04 -1.28296964e-04 -1.18785706e-04
#  -1.09289590e-04 -9.98197878e-05 -9.03867271e-05 -8.10001209e-05
#  -7.16690005e-05 -6.24017531e-05 -5.32061627e-05 -4.40894544e-05
#  -3.50583406e-05 -2.61190689e-05 -1.72774718e-05 -8.53901662e-06
#   9.11445515e-08  8.60812476e-06  1.70072534e-05  2.52840287e-05
#   3.34340721e-05  4.14530843e-05  4.93368052e-05  5.70809752e-05
#   6.46813011e-05  7.21334253e-05  7.94328981e-05  8.65751549e-05
#   9.35554975e-05  1.00369079e-04  1.07010895e-04  1.13475775e-04
#   1.19758384e-04  1.25853226e-04  1.31754647e-04  1.37456852e-04
#   1.42953920e-04  1.48239818e-04  1.53308434e-04  1.58153593e-04
#   1.62769098e-04  1.67148752e-04  1.71286402e-04  1.75175972e-04
#   1.78811505e-04  1.82187199e-04  1.85297455e-04  1.88136916e-04
#   1.90700511e-04  1.92983497e-04  1.94981502e-04  1.96690566e-04
#   1.98107181e-04  1.99228330e-04  2.00051520e-04  2.00574823e-04
#   2.00796900e-04  2.00717031e-04  2.00335145e-04  1.99651834e-04
#   1.98668374e-04  1.97386740e-04  1.95809613e-04  1.93940387e-04
#   1.91783168e-04  1.89342771e-04  1.86624715e-04  1.83635205e-04
#   1.80381120e-04  1.76869990e-04  1.73109970e-04  1.69109813e-04
#   1.64878834e-04  1.60426878e-04  1.55764275e-04  1.50901799e-04
#   1.45850623e-04  1.40622272e-04  1.35228568e-04  1.29681583e-04
#   1.23993586e-04  1.18176985e-04  1.12244275e-04  1.06207983e-04
#   1.00080614e-04  9.38745991e-05  8.76022380e-05  8.12756535e-05
#   7.49067398e-05  6.85071166e-05  6.20880847e-05  5.56605851e-05
#   4.92351608e-05  4.28219225e-05  3.64305180e-05  3.00701052e-05
#   2.37493294e-05  1.74763051e-05  1.12586015e-05  5.10323277e-06
#  -9.83347174e-07 -6.99524592e-06 -1.29271293e-05 -1.87742138e-05
#  -2.45322553e-05 -3.01975335e-05 -3.57668330e-05 -4.12374208e-05
#  -4.66070204e-05 -5.18737836e-05 -5.70362593e-05 -6.20933602e-05
#  -6.70443275e-05 -7.18886946e-05 -7.66262492e-05 -8.12569947e-05
#  -8.57811118e-05 -9.01989199e-05 -9.45108384e-05 -9.87173498e-05
#  -1.02818963e-04 -1.06816181e-04 -1.10709463e-04 -1.14499201e-04
#  -1.18185685e-04 -1.21769083e-04 -1.25249414e-04 -1.28626533e-04
#  -1.31900113e-04 -1.35069632e-04 -1.38134366e-04 -1.41093380e-04
#  -1.43945531e-04 -1.46689465e-04 -1.49323625e-04 -1.51846259e-04
#  -1.54255431e-04 -1.56549036e-04 -1.58724818e-04 -1.60780391e-04
#  -1.62713259e-04 -1.64520846e-04 -1.66200517e-04 -1.67749610e-04
#  -1.69165467e-04 -1.70445458e-04 -1.71587020e-04 -1.72587684e-04
#  -1.73445106e-04 -1.74157101e-04 -1.74721670e-04 -1.75137030e-04
#  -1.75401644e-04 -1.75514244e-04 -1.75473858e-04 -1.75279830e-04
#  -1.74931843e-04 -1.74429934e-04 -1.73774508e-04 -1.72966354e-04
#  -1.72006650e-04 -1.70896971e-04 -1.69639294e-04 -1.68235994e-04
#  -1.66689844e-04 -1.65004007e-04 -1.63182029e-04 -1.61227828e-04
#  -1.59145678e-04 -1.56940189e-04 -1.54616295e-04 -1.52179224e-04
#  -1.49634483e-04 -1.46987824e-04 -1.44245221e-04 -1.41412842e-04
#  -1.38497017e-04 -1.35504208e-04 -1.32440978e-04 -1.29313959e-04
#  -1.26129819e-04 -1.22895231e-04 -1.19616839e-04 -1.16301231e-04
#  -1.12954902e-04 -1.09584230e-04 -1.06195443e-04 -1.02794595e-04
#  -9.93875350e-05 -9.59798885e-05 -9.25770295e-05 -8.91840614e-05
#  -8.58057979e-05 -8.24467451e-05 -7.91110865e-05 -7.58026697e-05
#  -7.25249954e-05 -6.92812086e-05 -6.60740917e-05 -6.29060597e-05
#  -5.97791579e-05 -5.66950618e-05 -5.36550781e-05 -5.06601489e-05
#  -4.77108569e-05 -4.48074335e-05 -4.19497675e-05 -3.91374164e-05
#  -3.63696195e-05 -3.36453115e-05 -3.09631388e-05 -2.83214768e-05
#  -2.57184479e-05 -2.31519414e-05 -2.06196346e-05 -1.81190144e-05
#  -1.56474001e-05 -1.32019669e-05 -1.07797704e-05 -8.37777179e-06
#  -5.99286283e-06 -3.62189227e-06 -1.26169203e-06  1.09089618e-06
#   3.43899412e-06  5.78566016e-06  8.13386254e-06  1.04864527e-05
#   1.28461388e-05  1.52154599e-05  1.75967599e-05  1.99921628e-05
#   2.24035485e-05  2.48325284e-05  2.72804237e-05  2.97482429e-05
#   3.22366618e-05  3.47460039e-05  3.72762224e-05  3.98268842e-05
#   4.23971550e-05  4.49857861e-05  4.75911036e-05  5.02109991e-05
#   5.28429228e-05  5.54838789e-05  5.81304231e-05  6.07786624e-05
#   6.34242585e-05  6.60624320e-05  6.86879713e-05  7.12952427e-05
#   7.38782040e-05  7.64304209e-05  7.89450864e-05  8.14150424e-05
#   8.38328051e-05  8.61905923e-05  8.84803541e-05  9.06938057e-05
#   9.28224636e-05  9.48576829e-05  9.67906986e-05  9.86126677e-05
#   1.00314714e-04  1.01887972e-04  1.03323641e-04  1.04613026e-04
#   1.05747594e-04  1.06719020e-04  1.07519244e-04  1.08140515e-04
#   1.08575449e-04  1.08817075e-04  1.08858886e-04  1.08694888e-04
#   1.08319647e-04  1.07728331e-04  1.06916758e-04  1.05881430e-04
#   1.04619574e-04  1.03129177e-04  1.01409010e-04  9.94586626e-05
#   9.72785597e-05  9.48699823e-05  9.22350798e-05  8.93768802e-05
#   8.62992932e-05  8.30071098e-05  7.95059964e-05  7.58024839e-05
#   7.19039516e-05  6.78186062e-05  6.35554554e-05  5.91242778e-05
#   5.45355861e-05  4.98005877e-05  4.49311401e-05  3.99397016e-05
#   3.48392794e-05  2.96433735e-05  2.43659173e-05  1.90212161e-05
#   1.36238823e-05  8.18876929e-06  2.73090371e-06]

# %%
# 2. Locate points where the derivative changes from positive to negative.
# These points indicate the presence of a peak or local maximum in the KDE curve.

peaks = (derivative[:-1] > 0) & (derivative[1:] < 0)
print(peaks)
# Out:
# [False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False  True False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False  True False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False  True
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False False False False False False False False False False False
#  False False]

# %%
# 3. Extract the x-values corresponding to the identified peaks.
#  These x-values represent the locations of modes in the KDE.

peak_values = x_plot[1:-1][peaks]
print(peak_values)
# Out:
# [[ 0.05771149]
#  [ 4.07234957]
#  [ 8.31509208]
#  [12.42097193]]

# %%
# Plot modes
plt.scatter(peak_values, np.exp(kde.score_samples(peak_values.reshape(-1, 1))), color='green', marker='o', label='Modes')
plt.plot(x_plot, np.exp(log_dens), color='red', label='Kernel Density Estimate')
plt.title('KDE for 1D Data with Modes Identified')
plt.xlabel('Data Points')
plt.ylabel('Density')
plt.legend()
plt.show()

# %%
plt.hist(data, bins=30, density=True, alpha=0.7, color='blue', label='Histogram')
# Plot modes
plt.scatter(peak_values, np.exp(kde.score_samples(peak_values.reshape(-1, 1))), color='yellow', marker='o', label='Modes')
plt.plot(x_plot, np.exp(log_dens), color='red', label='Kernel Density Estimate')
plt.title('KDE for 1D Data with Modes Identified')
plt.xlabel('Data Points')
plt.ylabel('Density')
plt.legend()
plt.show()

# %% [markdown]
# ## KDE for 2d Data

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.neighbors import KernelDensity
from mpl_toolkits.mplot3d import Axes3D

# Function to generate 2D data with two peaks
def generate_bimodal_data():
    np.random.seed(42)
    data1 = np.random.multivariate_normal(mean=[-3, -3], cov=[[0.3, 0.5], [0.5, 1]], size=50)
    data2 = np.random.multivariate_normal(mean=[-2, 2], cov=[[1, -0.5], [-0.5, 1]], size=300)
    return np.concatenate([data1, data2])

# Generate bimodal 2D data
data_2d_bimodal = generate_bimodal_data()
print(data_2d_bimodal.shape)
# Out:
# (350, 2)

# %%
# Create a KDE model for 2D data
kde_2d_bimodal = KernelDensity(bandwidth=0.5, kernel='gaussian')
kde_2d_bimodal.fit(data_2d_bimodal)

# Generate points for plotting in 2D
x_plot = np.linspace(min(data_2d_bimodal[:, 0]), max(data_2d_bimodal[:, 0]), 100)
y_plot = np.linspace(min(data_2d_bimodal[:, 1]), max(data_2d_bimodal[:, 1]), 100)
x_plot, y_plot = np.meshgrid(x_plot, y_plot)
xy_plot = np.column_stack([x_plot.ravel(), y_plot.ravel()])

# Evaluate the KDE model on the generated points
log_dens_2d_bimodal = kde_2d_bimodal.score_samples(xy_plot)

# Reshape the results for contour plotting
log_dens_2d_bimodal = log_dens_2d_bimodal.reshape(x_plot.shape)

# Plot the original 2D data points
plt.scatter(data_2d_bimodal[:, 0], data_2d_bimodal[:, 1], alpha=0.5, color='blue', label='Data Points')

# Plot contours of the KDE estimate
plt.contour(x_plot, y_plot, np.exp(log_dens_2d_bimodal), levels=10, colors='red', linewidths=2)

plt.title('KDE for Bimodal 2D Data')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend()
plt.show()

# Visualize KDE peaks in 3D
fig = plt.figure(figsize=(10, 6))
ax = fig.add_subplot(111, projection='3d')

# Create meshgrid for 3D surface plot
x_plot_3d, y_plot_3d = np.meshgrid(x_plot[0, :], y_plot[:, 0])  # Use 1D arrays for meshgrid
z_plot_3d = np.exp(log_dens_2d_bimodal)

# Plot 3D surface
ax.plot_surface(x_plot_3d, y_plot_3d, z_plot_3d, cmap='viridis', edgecolor='k')

ax.set_title('3D Visualization of KDE Peaks')
ax.set_xlabel('X-axis')
ax.set_ylabel('Y-axis')
ax.set_zlabel('Density')

plt.show()

# %% [markdown]
# ## Exercise
# 1. Apply KDE in iris dataset and find how many modes are present in the dataset. Verify the number of modes with number of classes.
# 2. Apply different bandwidth selection algorithms and kernels and find the best for iris dataset.

# %%
from sklearn import datasets
iris=datasets.load_iris()
data=iris.data[:,(0,3)]

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
# Generate synthetic 2D data with three clusters
np.random.seed(42)
data1 = np.random.multivariate_normal([2, 2], [[1, 0.5], [0.5, 1]], 100)
data2 = np.random.multivariate_normal([6, 6], [[1, 0], [0, 1]], 100)
data3 = np.random.multivariate_normal([10, 2], [[1, -0.5], [-0.5, 1]], 100)
data = np.vstack([data1, data2, data3])
data.shape
plt.scatter(data[:,0], data[:,1])

# %%
from scipy.stats import gaussian_kde
from scipy.optimize import minimize

# %%
# Create a KDE object for the 2D data
kde = gaussian_kde(data.T)

# %%
# Define the negative sum of KDE function (to perform minimization)
neg_kde_sum = lambda x: -kde(x).sum()

# %%
# Choose starting points for optimization
start_points = np.array([[4, 2], [1, 6], [6, 6], [10,2], [20,8]])

# %%
# Perform optimization (gradient ascent) and store intermediate results
modes = []
optimization_steps = []
for start_point in start_points:
    result = minimize(neg_kde_sum, start_point, bounds=[(min(data[:, 0]), max(data[:, 0])), (min(data[:, 1]), max(data[:, 1]))])
    modes.append(result.x)
    optimization_steps.append(result.x)
    # print(result)

# %%
# Convert modes to numpy array for easier indexing
modes = np.array(modes)
modes
# Out:
# array([[ 2.11139135,  2.1730274 ],
#        [ 9.91113131,  1.83187911],
#        [ 6.10568494,  6.00353426],
#        [ 9.91265721,  1.83085037],
#        [11.99561766,  7.99999003]])

# %%
# Plot the original data, KDE contours, and highlight mode locations
plt.scatter(data[:, 0], data[:, 1], alpha=0.5, label='Data')

# %%
# plt.contourf(*np.meshgrid(np.linspace(min(data[:, 0]), max(data[:, 0]), 100), np.linspace(min(data[:, 1]), max(data[:, 1]), 100)), kde(np.meshgrid(np.linspace(min(data[:, 0]), max(data[:, 0]), 100), np.linspace(min(data[:, 1]), max(data[:, 1]), 100))), cmap='viridis', levels=10, alpha=0.5, label='KDE')
plt.scatter(modes[:, 0], modes[:, 1], color='red', marker='o', s=100, label='Modes')
plt.scatter(np.array(optimization_steps)[:, 0], np.array(optimization_steps)[:, 1], marker='x', color='green', label='Optimization Steps')
plt.legend()
plt.title("Multidimensional KDE with Mode Locations")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %%
from sklearn import datasets
iris=datasets.load_iris()

# %%
data=iris.data[:,(2,3)]

# %%
import pandas as pd
df=pd.read_csv('http://exoplanets.org/csv-files/exoplanets.csv')
df.head()
import seaborn as sns
df = df[['NAME', 'MSINI', 'A']].dropna()
df = df.rename(columns={'NAME': 'Name', 
                        'MSINI':'Mass', 
                        'A': 'Distance'}).set_index('Name').astype(float)
df
df = df.drop(df[df['Mass'] == 0].index)
with plt.style.context('seaborn'):
    sns.scatterplot(data=df, x='Mass', y='Distance')

plt.xscale('log')
plt.yscale('log')
plt.show()
data=df.iloc[:,].to_numpy()
data
# Out:
# C:\Users\vwadhawan\AppData\Local\Temp\ipykernel_26920\99632731.py:2: DtypeWarning: Columns (4,5,10,11,17,18,23,24,26,27,30,33,38,39,44,45,50,51,56,57,62,63,70,71,73,74,79,80,81,82,88,89,95,96,105,106,109,110,115,116,117,124,125,130,131,137,143,144,149,150,159,160,161,162,172,173,174,179,180,182,188,189,195,196,201,202,205,206,211,212,217,218,223,224,229,230,235,236,241,242,247,248,253,254,259,260,265,266,268,269,270,271,273,278,279,284,285,290,291,294,295,301,302,304,305,310,311) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('http://exoplanets.org/csv-files/exoplanets.csv')
# array([[0.310432 , 0.091351 ],
#        [7.65457  , 0.0367693],
#        [0.642621 , 3.70596  ],
#        ...,
#        [1.15082  , 0.0508651],
#        [0.595021 , 0.0388252],
#        [4.11582  , 2.52452  ]])

# %%
from scipy.stats import gaussian_kde
from scipy.optimize import minimize

# %%
# Create a KDE object for the 2D data
kde = gaussian_kde(data.T)

# %%
# Define the negative sum of KDE function (to perform minimization)
neg_kde_sum = lambda x: -kde(x).sum()

# %%
# Choose starting points for optimization
start_points = np.array([[4, 2], [1, 6], [6, 6], [10,2], [20,8]])

# %%
# Perform optimization (gradient ascent) and store intermediate results
modes = []
optimization_steps = []
for start_point in start_points:
    result = minimize(neg_kde_sum, start_point, bounds=[(min(data[:, 0]), max(data[:, 0])), (min(data[:, 1]), max(data[:, 1]))])
    modes.append(result.x)
    optimization_steps.append(result.x)
    # print(result)

# %%
# Convert modes to numpy array for easier indexing
modes = np.array(modes)
modes
# Out:
# array([[ 0.54207003,  0.09748605],
#        [ 0.54210398,  0.09748771],
#        [ 5.55194422,  6.44223123],
#        [ 9.74422467,  1.36657675],
#        [20.        ,  6.45931   ]])

# %%
# Plot the original data, KDE contours, and highlight mode locations
plt.scatter(data[:, 0], data[:, 1], alpha=0.5, label='Data')

# %%
# plt.contourf(*np.meshgrid(np.linspace(min(data[:, 0]), max(data[:, 0]), 100), np.linspace(min(data[:, 1]), max(data[:, 1]), 100)), kde(np.meshgrid(np.linspace(min(data[:, 0]), max(data[:, 0]), 100), np.linspace(min(data[:, 1]), max(data[:, 1]), 100))), cmap='viridis', levels=10, alpha=0.5, label='KDE')
plt.scatter(modes[:, 0], modes[:, 1], color='red', marker='o', s=100, label='Modes')
plt.scatter(np.array(optimization_steps)[:, 0], np.array(optimization_steps)[:, 1], marker='x', color='green', label='Optimization Steps')
plt.legend()
plt.title("Multidimensional KDE with Mode Locations")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()
