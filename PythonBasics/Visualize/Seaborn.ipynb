# %% [markdown]
# # Visualization using Seaborn
# * Seaborn is a data visualization library built on top of Matplotlib and integrates closely with pandas data structures.

# %% [markdown]
# # Functionalities of Seaborn
# * Allows comparison between multiple variables
# * Supports multi-plot grids
# * Univariate and bivariate visualization
# * Availability of different color palettes
# * Estimates and plots linear regression line

# %% [markdown]
# # Difference Between Matplotlib VS Seaborn
# [Check here](https://www.geeksforgeeks.org/difference-between-matplotlib-vs-seaborn/)

# %% [markdown]
# # Dependencies
# Consider the following dependencies of Seaborn −
#
# * Python 2.7 or 3.4+
# *numpy
# *scipy
# *pandas
# *matplotlib

# %% [markdown]
# # Installation
# ```
# pip install seaborn
# ```
#
# or
#
# ```
# conda install seaborn
#
# ```

# %%
import seaborn as sns
sns.__version__
# Out:
# '0.11.2'

# %% [markdown]
# # Seaborn Dataset
# * Seaborn comes with a few important datasets in the library. When Seaborn is installed, the datasets download automatically.
#
# * You can use any of these datasets for your learning. With the help of the following function you can load the required dataset

# %% [markdown]
# ## Existing datasets

# %%
import seaborn as sns
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %% [markdown]
# ## Load Dataset
# * Syntax
# ```
# sns.load_dataset()
# ```

# %%
import seaborn as sns
df=sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# # Seaborn Figure Styles
# The set_style() function allows you to set the theme of the plot. As per the latest updated version, below are the five themes available.
#
# * Darkgrid
# * Whitegrid
# * Dark
# * White
# * Ticks

# %%
import seaborn as sns
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
sns.set_style("ticks")
sinplot()
plt.show()

# %% [markdown]
# ## Removing Axes Spines
# * In the white and ticks themes, we can remove the top and right axis spines using the despine() function.
# * In the regular plots, we use left and bottom axes only. Using the despine() function, we can avoid the unnecessary right and top axes spines, which is not supported in Matplotlib.

# %%
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
import seaborn as sb
sb.set_style("whitegrid")
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# ## Overriding the style elements
# * If you want to customize the Seaborn styles, you can pass a dictionary of parameters to the set_style() function. Parameters available are viewed using axes_style() function.

# %%
import seaborn as sb
sb.axes_style()
# Out:
# {'axes.facecolor': 'white',
#  'axes.edgecolor': '.8',
#  'axes.grid': True,
#  'axes.axisbelow': True,
#  'axes.labelcolor': '.15',
#  'figure.facecolor': 'white',
#  'grid.color': '.8',
#  'grid.linestyle': '-',
#  'text.color': '.15',
#  'xtick.color': '.15',
#  'ytick.color': '.15',
#  'xtick.direction': 'out',
#  'ytick.direction': 'out',
#  'lines.solid_capstyle': <CapStyle.round: 'round'>,
#  'patch.edgecolor': 'w',
#  'patch.force_edgecolor': True,
#  'image.cmap': 'rocket',
#  'font.family': ['sans-serif'],
#  'font.sans-serif': ['Arial',
#   'DejaVu Sans',
#   'Liberation Sans',
#   'Bitstream Vera Sans',
#   'sans-serif'],
#  'xtick.bottom': False,
#  'xtick.top': False,
#  'ytick.left': False,
#  'ytick.right': False,
#  'axes.spines.left': True,
#  'axes.spines.bottom': True,
#  'axes.spines.right': True,
#  'axes.spines.top': True}

# %%
import numpy as np
from matplotlib import pyplot as plt
def sinplot(flip=1):
   x = np.linspace(0, 14, 100)
   for i in range(1, 5):
      plt.plot(x, np.sin(x + i * .5) * (7 - i) * flip)
import seaborn as sb
# changing the style here
sb.set_style("darkgrid", {'axes.axisbelow': True})
sinplot()
sb.despine()
plt.show()

# %% [markdown]
# # Strip Plot
# * It is similar to the scatter plot with one categorical variable
# * It is used to understand the underlying distribution of the data
# * One axis represents the categorical variable and another represents the value corresponding to the categories

# %%
import pandas as pd
df_titanic=pd.read_csv('data/Titanic_data.csv')
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ## Check the distribution of age based on gender
# * observation : The plot shows that, the maximum age of males is higher than of females

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x='Sex', y='Age', data=df_titanic)
plt.title('Strip plot for age and sex')
plt.show()

# %% [markdown]
# ## Add one more categorical variable to strip plot using the parameter, ‘hue’
# * Observation : Proportion of female survivors is higher than males

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.stripplot(x='Sex', y='Age', hue='Survived',  data=df_titanic)
plt.title('survival based on age and sex')
plt.show()

# %% [markdown]
# ## Exercise
# Load the iris dataset from seabron and show striplot of species vs patel length

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('iris')
sb.stripplot(x = "species", y = "petal_length", data = df)
plt.show()

# %% [markdown]
# # Distribution Plot
# * It displays the distribution of the data
# * It is a variation of histogram that uses kernel smoothing to plot values, allowing for smoother distributions by smoothing out the noise
# * The distplot() method plots the histogram with a Kernel Density Estimator (KDE), which is a used to estimate the probability distribution function of a random variable

# %% [markdown]
# ## Insurance claim distribution
# * Observation : The plot shows the positive skewness of the ‘claim’ variable

# %%
import pandas as pd
df=pd.read_csv('data/insurance_data.csv')
df.head(2)
# Out:
#    PatientID  age gender   bmi  bloodpressure diabetic  children smoker  \
# 0          1   39   male  23.2             91      Yes         0     No
# 1          2   24   male  30.1             87       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(a=df['claim'])
plt.title('Claim distribution')
plt.show()
# Out:
# C:\Vipul\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ## Plot the distribution of Claim without the kernel density estimator (KDE)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.distplot(a=df['claim'], color='olive', kde=False)
plt.title('Claim distribution')
plt.show()
# Out:
# C:\Vipul\Anaconda\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # Joint Plot
# * A joint plot is a bivariate plot along with the distribution plot along the margins

# %%
import pandas as pd
df=pd.read_csv('data/insurance_data.csv')
df.head(2)
# Out:
#    PatientID  age gender   bmi  bloodpressure diabetic  children smoker  \
# 0          1   39   male  23.2             91      Yes         0     No
# 1          2   24   male  30.1             87       No         0     No
#
#       region    claim
# 0  southeast  1121.87
# 1  southeast  1131.51

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.jointplot(x='bmi',y='claim', color='sandybrown', data=df)
plt.title('Claim distribution')
plt.show()

# %% [markdown]
# # Violin Plot
# * Violin Plots are a combination of the box plot with the kernel density estimates. So, these plots are easier to analyze and understand the distribution of the data.
# * It is similar to a boxplot, that displays the kernel density estimator of the underlying distribution
# * It shows the distribution of the quantitative data across categorical variables such that those distributions can be compared
#
# * NOTE : The box plot is plotted inside the violin plot

# %%
import pandas as pd
df_titanic=pd.read_csv('data/Titanic_data.csv')
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.violinplot(x='Sex', y='Age',  data=df_titanic)
plt.title('survival based on age and sex')
plt.show()

# %% [markdown]
# ### Violin plot can be divided into two halves, where one half represents surviving while other half represents the non-surviving passenger
# * Pass ‘True’ as value for the split parameter

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.violinplot(x='Sex', y='Age',  data=df_titanic, hue='Survived', split=True)
plt.title('survival based on age and sex')
plt.show()

# %% [markdown]
# ## Exercise
# Load tips dataset from seaborn and show totall_bill distribution based on days in a violin plot

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.violinplot(x = "day", y = "total_bill", data=df)
plt.show()

# %% [markdown]
# ## Exercise
# Load tips dataset from seaborn and show totall_bill distribution based on days in a violin plot for different sex

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.violinplot(x = "day", y = "total_bill",hue = 'sex', data = df)
plt.show()

# %% [markdown]
# # Swarm Plot
# * It is the combination of strip and violin plots
# * The points are adjusted in such a way that they don't overlap, which gives the better representation of the data

# %%
import pandas as pd
df_titanic=pd.read_csv('data/Titanic_data.csv')
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ## Create a swarm plot for the distribution of age based on gender
# Observation : High proportion of males are in the age range 20 - 40

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.swarmplot(x='Sex', y='Age',  data=df_titanic, hue='Survived')
plt.title('survival based on age and sex')
plt.show()

# %% [markdown]
# # Pair Plot
# * It displays the pairwise relationship between the numeric variables
# * The pairplot() method creates a matrix; where the diagonal plots represent the univariate distribution of each variable and the off-diagonal plots represent the scatter plot of the pair of variables

# %%
import pandas as pd
df_titanic=pd.read_csv('data/iris.csv')
df_titanic.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.pairplot( data=df_titanic, hue='species')
plt.title('Feature Pairwise plot')
plt.show()

# %% [markdown]
# # Count Plot
# * It is similar to the bar plot.

# %%
import pandas as pd
df_titanic=pd.read_csv('data/Titanic_data.csv')
df_titanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked
# 0      0  A/5 21171   7.2500   NaN        S
# 1      0   PC 17599  71.2833   C85        C

# %% [markdown]
# ## Gender wise count

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.countplot(x='Sex',data=df_titanic)
plt.title('Gender wise count of passengers')
plt.show()

# %% [markdown]
# # Regression Plot
# * It is used to study the relationship between the two variables with the regression line

# %%
import pandas as pd
df_titanic=pd.read_csv('data/iris.csv')
df_titanic.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.regplot(x='sepal_length', y='petal_length', data=df_titanic)
plt.title('Regression Plot')
plt.show()

# %% [markdown]
# ## Exercise
# load tips dataset from seabron and find the relation between tips vs total bill using a regression plot

# %%
import pandas as pd
import seaborn as sb
from matplotlib import pyplot as plt
df = sb.load_dataset('tips')
sb.regplot(x = "total_bill", y = "tip", data = df)
plt.show()

# %% [markdown]
# # Heatmap
# * A heatmap is a two-dimensional graphical representation of data where the individual values that are contained in a matrix are represented by the different colors
# * Heatmap for correlation shows the correlation between the variables on each axis

# %%
import pandas as pd
df_titanic=pd.read_csv('data/iris.csv')
df_titanic.head(2)
# Out:
#    sepal_length  sepal_width  petal_length  petal_width      species
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa

# %%
import seaborn as sns
import matplotlib.pyplot as plt
#cbar- color bar
# annot If True, write the data value in each cell.
# cmap The mapping from data values to color space.
# linewidth line between cells
correlation=df_titanic.corr()
print(correlation)
sns.heatmap(data=correlation, annot=True, cmap='Reds', cbar=False, linewidth=0.5)
plt.title('Correlation Plot')
plt.show()
# Out:
#               sepal_length  sepal_width  petal_length  petal_width
# sepal_length      1.000000    -0.109369      0.871754     0.817954
# sepal_width      -0.109369     1.000000     -0.420516    -0.356544
# petal_length      0.871754    -0.420516      1.000000     0.962757
# petal_width       0.817954    -0.356544      0.962757     1.000000

# %% [markdown]
# # Multiple plots with seaborn

# %%
import matplotlib.pyplot as plt
import seaborn as sns
df=sns.load_dataset('penguins')
print(df.head())
fig, axs = plt.subplots(1,3, figsize=(20,5))
sns.countplot(x='species', data=df, ax=axs[0])
# sns.barplot(x='island', data=df, ax=axs[1])
sns.barplot(data=df, x="island", y="body_mass_g", ax=axs[1])
sns.scatterplot(data=df, x="bill_length_mm", y="bill_depth_mm", ax=axs[2])
axs[0].set_title('Chart 1')
axs[1].set_title('Chart 2')
axs[2].set_title('Chart 3')
plt.show()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 3  Adelie  Torgersen             NaN            NaN                NaN
# 4  Adelie  Torgersen            36.7           19.3              193.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 3          NaN     NaN
# 4       3450.0  Female
