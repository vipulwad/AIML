# %% [markdown]
# ## What are images?
#
# The computer reads any image as a range of values between 0 and 255.
#
# **For any color image, there are 3 primary channels – Red, green and blue.**
#
# A matrix is formed for every primary color and later these matrices combine to provide a Pixel value for the individual R, G, B colors.
# ![flower.jpg](data:image/jpeg;base64,...)
#
# **Note: For a black-white image, there is only one single channel.**

# %% [markdown]
# # OpenCV
# Compared to other languages like C/C++, Python is slower. But another important feature of Python is that it can be easily extended with C/C++. This feature helps us to write computationally intensive codes in C/C++ and create a Python wrapper for it so that we can use these wrappers as Python modules.
#
# #### This gives us two advantages:
# * First, our code is as fast as original C/C++ code (since it is the actual C++ code working in background) and
# * Second, it is very easy to code in Python. This is how OpenCV-Python works, it is a Python wrapper around original C++ implementation.
#
# And the support of Numpy makes the task easier. All the OpenCV array structures are converted to-and-from Numpy arrays.

# %% [markdown]
# # Applications of opencv
# * Robotics Application
# * Medicine Application
# * Industrial Automation Application
# * Security Application
# * Transportation Application

# %% [markdown]
# # Features of OpenCV Library
# 1. Using OpenCV library, you can −
#
# 2. Read and write images
#
# 3. Capture and save videos
#
# 4. Process images (filter, transform)
#
# 5. Perform feature detection
#
# 6. Detect specific objects such as faces, eyes, cars, in the videos or images.
#
# 7. Analyze the video, i.e., estimate the motion in it, subtract the background, and track objects in it.

# %% [markdown]
# ## Install OpenCV

# %%
! pip install opencv-python

# %% [markdown]
# # Connect google drive to Colab

# %%
# /content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## Import Libraries

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# fix the figure size for matplotlib
plt.rcParams['figure.figsize'] = [10,8]

# %% [markdown]
# ## Load image - imread()
# ```
# cv2.imread(filepath, flag)
# ```
# Flags:
# ```
# cv2.IMREAD_UNCHANGED  or -1
# cv2.IMREAD_GRAYSCALE  or 0
# cv2.IMREAD_COLOR  or 1
# ```

# %%
## Load correct image
img = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png',
                 1)

# %%
print(img)

# %%
img.shape

# %%
y=np.max(img, axis=1)
y.shape

# %% [markdown]
# ## Show image using Cv2 - imshow()
# ```
# cv2.imshow(window_name, image)
# ```
#
# **window_name**: A string representing the name of the window in which image to be displayed.

# %%
cv2.imshow(img)

# %%
from google.colab.patches import cv2_imshow
    
cv2_imshow(img)  # Pay special attention to "_" (underscore)

# %% [markdown]
# ## Show image using Matplotlib - imshow()

# %%
plt.imshow(img)
plt.show()

# %% [markdown]
# ** Matplotlib expects different order of RGB channel when compared to OpenCV **
#
# - Matplotlib ---> RGB (Red, Green, Blue)
# - OpenCV ---> BGR (Blue, Green, Red)

# %% [markdown]
# ## Change Channel, color - cvtColor()
# ```
#  cv2.cvtColor(image, [colorCode])
# ```
#
# [Color Codes](https://docs.opencv.org/3.4/d8/d01/group__imgproc__color__conversions.html)

# %% [markdown]
# ## Convert RGB to HSV, HLS
# * An RGB (colored) image has three channels, Red, Blue and Green. A colored image in OpenCV has a shape in [H, W, C] format, where H, W, and C are image height, width and number of channels. All three channels have a value range between 0 and 255.
#
# * The HSV image also has three channels, the Hue, Saturation and Value channels. In OpenCV, the values of the Hue channel range from 0 to 179, whereas the Saturation and Value channels range from 0 to 255.
#
# * An HLS image also has three channels, the Hue, Lightness and Saturation channels. In OpenCV, the values of the Hue channel range from 0 to 179 whereas the Lightness and Saturation channels range from 0 to 255.

# %%
img2 = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png')

plt.imshow(img2)

# %% [markdown]
# ### to RGB

# %%
to_rgb = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)

plt.imshow(to_rgb)

# %% [markdown]
# ### to HSV

# %%
to_hsv = cv2.cvtColor(img2, cv2.COLOR_RGB2HSV)

plt.imshow(to_hsv)

# %% [markdown]
# ### to HLS

# %%
to_hls = cv2.cvtColor(img2, cv2.COLOR_RGB2HLS)

plt.imshow(to_hls)

# %%
# convert to RGB

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

print("Image Shape: ", img.shape)
plt.imshow(img)

# %% [markdown]
# ## Save the image - imwrite()
# ```
# cv2.imwrite(filename, image)
# ```

# %%
# Load the image in gray scale
# -1 means image as it is. 0 means grayscale. 1 means RGB.
img_orig = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', -1) 
img_gray = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', 0)
img_rgb = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', 1)
print('Image Shape: ', img_gray.shape)
print('Image Shape: ', img_orig.shape)
print('Image Shape: ', img_rgb.shape)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
cv2_imshow(img_gray)

# %%
img_gray

# %%
cv2.imwrite('/content/dog.jpg', img_gray)

# %% [markdown]
# ## Exercise
# Download image from google, read it, then display using matplotlib, cv.imshow()

# %%
# !wget https://img.freepik.com/free-photo/purple-osteospermum-daisy-flower_1373-16.jpg -O abc.jpg

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img_orginal=cv2.imread('xyz.jpg', -1)
img_grey=cv2.imread('xyz.jpg', 0)
img_rgb=cv2.imread('xyz.jpg', 1)

# %%
print(img_orginal.shape)
print(img_grey.shape)
print(img_rgb.shape)

# %%
cv2_imshow(img_grey)

# %%
plt.imshow(img_grey, cmap='gray')

# %%
plt.imshow(img_rgb)

# %% [markdown]
# ## Exercise
# Read an Image using cv2 and save it in HSL format.

# %%
img_rgb=cv2.imread('abc.jpg', 1)
flower = cv2.cvtColor(img_rgb,cv2.COLOR_RGB2HLS)
plt.imshow(flower)

# %% [markdown]
# ## Resize image - resize()
# ```
# cv2.resize(source, dsize, dest, fx, fy, interpolation)
# ```
# * source: Input Image array (Single-channel, 8-bit or floating-point)
# * dsize: Size of the output array
# * dest: Output array (Similar to the dimensions and type of Input image array) [optional]
# * fx: Scale factor along the horizontal axis  [optional]
# * fy: Scale factor along the vertical axis  [optional]
# * interpolation: One of the above interpolation methods  [optional]
#   * cv2.INTER_AREA: This is used when we need to shrink an image.
#   * cv2.INTER_CUBIC: This is slow but more efficient.
#   * cv2.INTER_LINEAR: This is primarily used when zooming is required. This is the default interpolation technique in OpenCV.

# %%
img = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', 1)

# %%
resize_img = cv2.resize(img, (600,400)) # Provide in WxH
print(resize_img.shape) # Returns HXW
plt.imshow(resize_img)

# %%
resize_shrink = cv2.resize(img, (100,100)) # Provide in WxH
print(resize_shrink.shape) # Returns HXW
plt.imshow(resize_shrink)

# %% [markdown]
# ### Resize image by ratio

# %%
ratio_resize = cv2.resize(img, (0,0),  fx=0.13, fy=0.75)

plt.imshow(ratio_resize)
print('Image size: ',ratio_resize.shape)

# %%
img.shape

# %% [markdown]
# ### Resize image by interpolation

# %%
shrink_image = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_AREA)
plt.imshow(shrink_image)
print('Image size: ',shrink_image.shape)

# %%
shrink_image = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_CUBIC)
plt.imshow(shrink_image)
print('Image size: ',shrink_image.shape)

# %%
shrink_image = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_LINEAR)
plt.imshow(shrink_image)
print('Image size: ',shrink_image.shape)

# %%
shrink_image = cv2.resize(img, (100, 100),
               interpolation = cv2.INTER_NEAREST)
plt.imshow(shrink_image)
print('Image size: ',shrink_image.shape)

# %% [markdown]
# ## Flip image - flip()

# %%
img = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', 1)

# %%
plt.imshow(img)

# %%
# flip the image
#-1 - Both, 0 - vertical, 1,2,etc - horizontal.
flip_img = cv2.flip(img, flipCode=2)  

plt.imshow(flip_img)
plt.show()

# %% [markdown]
# ## Drawing on image

# %%
blank_img = np.zeros(shape=(512,512,3))
blank_img.shape
blk_img1 = blank_img.copy()

# %%
white_img = np.full((512,512,3),127 )
white_img

# %%
blk_img1.max()

# %%
plt.imshow(blk_img1)
plt.show()

# %% [markdown]
# ### rectangle()

# %%
cv2.rectangle(blk_img1, 
              pt1=(400,400), 
              pt2=(250,100), 
              color=(0.4,0.7,0.9),
              thickness=2)
plt.imshow(blk_img1)

# %%
## another rectangle
cv2.rectangle(blank_img, pt1=(100,480), pt2=(20,420), color=(.2,.50,.180), thickness=5)
plt.imshow(blank_img)

# %% [markdown]
# ### circle()

# %%
cv2.circle(blank_img, center=(120,120), radius=60, color=(1,1,1), thickness=5)
plt.imshow(blank_img)

# %%
cX=blank_img.shape[0]
cY=blank_img.shape[0]
ex_CX, ex_CY=cX/2, cY/2
ex_CX, ex_CY

# %%
blank_img = np.zeros(shape=(512,512,3))

# %%
cv2.circle(blank_img, center=(int(ex_CX),int(ex_CY)), radius=60, color=(1,0,1), thickness=1)
plt.imshow(blank_img)

# %%
cv2.circle(blank_img, center=(200,200), radius=60, color=(1,0,1), thickness=-1)
plt.imshow(blank_img)

# %%
cv2.rectangle(blank_img, pt1=(200,480), pt2=(200,420), color=(.2,.50,.180), thickness=-1)
plt.imshow(blank_img)

# %% [markdown]
# ### line()

# %%
blank_img = np.zeros(shape=(512,512,3))

# %%
# line
blk_img1 = blank_img
cv2.line(blk_img1, pt1=(120,120), pt2=(440,340), color=(1,1,0), thickness=3)

plt.imshow(blk_img1)

# %% [markdown]
# ### Add text to the image - putText()

# %%
## choose font
font = cv2.FONT_HERSHEY_SCRIPT_COMPLEX#cv2.FONT_HERSHEY_COMPLEX
# FONT_HERSHEY_SIMPLEX
# FONT_HERSHEY_PLAIN
# FONT_HERSHEY_DUPLEX
# FONT_HERSHEY_COMPLEX
# FONT_HERSHEY_TRIPLEX
# FONT_HERSHEY_COMPLEX_SMALL 
# FONT_HERSHEY_SCRIPT_SIMPLEX
# FONT_HERSHEY_SCRIPT_COMPLEX
# FONT_ITALIC
blank_img = np.zeros(shape=(512,512,3))
cv2.putText(blank_img, text='sample text', org=(0,200), fontFace=font,
    fontScale=9, color=(0,1,1), thickness=1, lineType=cv2.LINE_AA)
plt.imshow(blank_img)

# %% [markdown]
# ### Draw a rectangle on dog face

# %%
img = cv2.imread('/content/drive/MyDrive/IMARTICUS/IPYNB/opencv/openCV-data/chicky_512.png', 1)

# %%
cv2.rectangle(img, (410,50), (100,350), (0,255,0), 3)
plt.imshow(img)

# %% [markdown]
# ## Exercise
# Take an dog image read it using opencv, write dogs name on it, draw a circle on the face of the dog.
