# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Basic Operations on Images
# * Access pixel values and modify them
# * Access image properties
# * Set a Region of Interest (ROI)
# * Split and merge images

# %% [markdown]
# ## Access pixel values and modify them

# %%
img=cv2.imread('data/flower.jpg', 1)
img=cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %%
px=img[100,100]
print(px)
# Out:
# [245 175 106]

# %% [markdown]
# ## Modify the pixel values

# %%
img2=img.copy()
plt.imshow(img)

# %%
img2[700:1500, 700:1500]=255
plt.imshow(img2)

# %% [markdown]
# ## Get a Region of Interest (ROI)

# %%
small_flower=img[500:1200, 500:1000]
plt.imshow(small_flower)

# %% [markdown]
# ### Exercise
# Take a person's image and crop the face

# %% [markdown]
# ## Splitting and Merging Image Channels

# %%
b,g,r = cv2.split(img)

# %%
plt.imshow(b)

# %%
plt.imshow(g)

# %%
plt.imshow(r)

# %%
# merge channels
img = cv2.merge((b,g,r))
plt.imshow(img)

# %%
# accesing through index
b1=img[:,:,0]
plt.imshow(b1)

# %% [markdown]
# # Arithmetic Operations on Images

# %% [markdown]
# ## Image Addition

# %%
x = np.uint8([250])
y = np.uint8([10])
print( cv2.add(x,y) ) # 250+10 = 260 => 255
print( x+y )          # 250+10 = 260 % 256 = 4
# Out:
# [[255]]
# [4]

# %%
img1=cv2.imread('data/flower.jpg', 1)
plt.imshow(img1)

# %%
img2=cv2.imread('data/flower2.jpg', 1)
plt.imshow(img2)

# %%
img3=cv2.add(img1,img2)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_26492\590700246.py in <module>
# ----> 1 img3=cv2.add(img1,img2)
#
# error: OpenCV(4.7.0) D:\a\opencv-python\opencv-python\opencv\modules\core\src\arithm.cpp:650: error: (-209:Sizes of input arguments do not match) The operation is neither 'array op array' (where arrays have the same size and the same number of channels), nor 'array op scalar', nor 'scalar op array' in function 'cv::arithm_op'

# %%
print(img1.shape, img2.shape)
# Out:
# (682, 1024, 3) (2736, 3648, 3)

# %%
## resize both the image so that we can blend

img_1 = cv2.resize(img1, (400,400))
img_2 = cv2.resize(img2, (400,400))

print(img_1.shape, img_2.shape)
# Out:
# (400, 400, 3) (400, 400, 3)

# %%
img3=cv2.add(img_1,img_2)

# %%
plt.imshow(img3)

# %% [markdown]
# ## Image Blending
# ```
#
# cv2.addWeighted()
#
# ```
# * src1	first input array.
# * alpha	weight of the first array elements.
# * src2	second input array of the same size and channel number as src1.
# * beta	weight of the second array elements.
# * gamma	scalar added to each sum.

# %%
img_1 = cv2.imread('data/dog_backpack.jpg')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

img_2 = cv2.imread('data/watermark_no_copy.png')
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

# %%
## resize both the image so that we can blend

img_1 = cv2.resize(img_1, (400,400))
img_2 = cv2.resize(img_2, (400,400))

# %%
blend = cv2.addWeighted(src1=img_1, alpha=.9, src2=img_2, beta=.1, gamma=0)
plt.imshow(blend)

# %% [markdown]
# ## Subtraction of Image
# ```
# cv2.subtract(src1, src2)
# ```

# %%
# path to input images are specified and  
# images are loaded with imread command 
image1 = cv2.imread('data/input1.jpg') 
plt.imshow(image1)

# %%
image2 = cv2.imread('data/input2.jpg')
plt.imshow(image2)

# %%
print(image1.shape, image2.shape)
# Out:
# (168, 300, 3) (168, 300, 3)

# %%
  
# cv2.subtract is applied over the
# image inputs with applied parameters
sub = cv2.subtract(image1, image2)
  
# the window showing output image
# with the subtracted image 

plt.imshow(sub)

# %% [markdown]
# # Image Overlaying

# %%
import cv2
import matplotlib.pyplot as plt

# %%
img_1 = cv2.imread('data/dog_backpack.jpg')
img_1 = cv2.cvtColor(img_1, cv2.COLOR_BGR2RGB)

img_2 = cv2.imread('data/watermark_no_copy.png')
img_2 = cv2.cvtColor(img_2, cv2.COLOR_BGR2RGB)

# %%
img_2 = cv2.resize(img_2, (400,400))
plt.imshow(img_2)

# %%
img_1[0:(0+img_2.shape[1]), 0:(0+img_2.shape[0])] = img_2

plt.imshow(img_1)

# %% [markdown]
# ### Exercise
# Take two image and overlay on each other.

# %% [markdown]
# # Create mask

# %% [markdown]
# ## bitwise_not()

# %%
# get pure white mask
import cv2
import matplotlib.pyplot as plt
import numpy as np

blank = np.zeros((400,400), dtype='uint8')
rectangle = cv2.rectangle(blank.copy(), (30,30), (370,370), 255, -1)


plt.imshow(rectangle, cmap='gray')

# %%
circle = cv2.circle(blank.copy(), (200,200), 200, 255, -1)
plt.imshow(circle, cmap='gray')

# %%
bitwise_not = cv2.bitwise_not(circle)
plt.imshow(bitwise_not, cmap='gray')

# %% [markdown]
# ## bitwise_or()
# * bitwise OR --> non-intersecting and intersecting regions

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

blank = np.zeros((400,400), dtype='uint8')
rectangle = cv2.rectangle(blank.copy(), (30,30), (370,370), 255, -1)
plt.imshow(rectangle, cmap='gray')

# %%
circle = cv2.circle(blank.copy(), (200,200), 200, 255, -1)
plt.imshow(circle, cmap='gray')

# %%
bitwise_or = cv2.bitwise_or(rectangle, circle) # Or operation with mask gives NAND operation.
plt.imshow(bitwise_or, cmap='gray')

# %% [markdown]
# ## bitwise_xor()
# * bitwise XOR --> non-intersecting regions

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

blank = np.zeros((400,400), dtype='uint8')
rectangle = cv2.rectangle(blank.copy(), (30,30), (370,370), 255, -1)
plt.imshow(rectangle, cmap='gray')

# %%
circle = cv2.circle(blank.copy(), (200,200), 200, 255, -1)
plt.imshow(circle, cmap='gray')

# %%
bitwise_xor = cv2.bitwise_xor(rectangle, circle)
plt.imshow(bitwise_xor, cmap='gray')

# %% [markdown]
# ## bitwise_and()

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

blank = np.zeros((400,400), dtype='uint8')
rectangle = cv2.rectangle(blank.copy(), (30,30), (370,370), 255, -1)
plt.imshow(rectangle, cmap='gray')

# %%
circle = cv2.circle(blank.copy(), (200,200), 200, 255, -1)
plt.imshow(circle, cmap='gray')

# %%
# bitwise AND --> intersecting regions
bitwise_and = cv2.bitwise_and(rectangle, circle)
plt.imshow(bitwise_and, cmap='gray')

# %%
img=cv2.imread('data/Nadia_Murad.jpg',1)
img=cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
# create a rectangle around the face
rectangle = cv2.rectangle(img, (70,60), (380,450), 255, 2)
plt.imshow(img)
